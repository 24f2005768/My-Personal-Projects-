# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Week1_GA_dataset.csv")

# %%
df.head()
# Out:
#          Date  Year    Locality  Estimated Value  Sale Price       Property  \
# 0  2009-01-02  2009   Waterbury         111440.0    185000.0  Single Family
# 1  2009-01-02  2009  Bridgeport         124670.0    150000.0     Two Family
# 2  2009-01-02  2009   Waterbury          55720.0    140000.0  Single Family
# 3  2009-01-02  2009  Bridgeport        4775276.0    272900.0  Single Family
# 4  2009-01-02  2009  Bridgeport         112351.0    210000.0              ?
#
#       Residential  num_rooms  num_bathrooms  carpet_area  property_tax_rate  \
# 0  Detached House          3              3        996.0           1.025953
# 1          Duplex          4              3       1241.0           1.025953
# 2  Detached House          3              2        910.0           1.025953
# 3  Detached House          3              1        971.0           1.025953
# 4  Detached House          3              2       1092.0           1.025953
#
#     Face
# 0  South
# 1  South
# 2  South
# ...

# %% [markdown]
# ### Question 1

# %%
df.isna().sum()
# Out:
# Date                    0
# Year                    0
# Locality             1253
# Estimated Value      1243
# Sale Price              0
# Property                0
# Residential             0
# num_rooms               0
# num_bathrooms           0
# carpet_area          1229
# property_tax_rate       0
# Face                    0
# dtype: int64

# %%
df.isin(['?']).sum()
# Out:
# Date                    0
# Year                    0
# Locality                0
# Estimated Value         0
# Sale Price              0
# Property             1823
# Residential             0
# num_rooms               0
# num_bathrooms           0
# carpet_area             0
# property_tax_rate       0
# Face                    0
# dtype: int64

# %% [markdown]
# ### Question 2

# %%
df.shape
# Out:
# (10000, 12)

# %% [markdown]
# ### Question 3

# %%
df.iloc[692, 0]
# Out:
# '2009-11-16'

# %% [markdown]
# ### Question 4

# %%
df.iloc[546, 7]
# Out:
# np.int64(3)

# %% [markdown]
# ### Question5

# %%
df.Locality.unique()
# Out:
# <ArrowStringArray>
# [    'Waterbury',    'Bridgeport',     'Greenwich',       'Norwalk',
#              nan,     'Fairfield', 'West Hartford',      'Stamford']
# Length: 8, dtype: str

# %% [markdown]
# ### Question 6

# %%
df.replace('?', np.nan, inplace=True)
# Out:
#             Date  Year    Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009   Waterbury         111440.0    185000.0
# 1     2009-01-02  2009  Bridgeport         124670.0    150000.0
# 2     2009-01-02  2009   Waterbury          55720.0    140000.0
# 3     2009-01-02  2009  Bridgeport        4775276.0    272900.0
# 4     2009-01-02  2009  Bridgeport         112351.0    210000.0
# ...          ...   ...         ...              ...         ...
# 9995  2022-09-30  2022  Bridgeport         153660.0    322000.0
# 9996  2022-09-30  2022  Bridgeport         109820.0    340000.0
# 9997  2022-09-30  2022   Waterbury          83210.0    170000.0
# 9998  2022-09-30  2022         NaN         216420.0    415000.0
# 9999  2022-09-30  2022     Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...

# %%
df.isna().sum()
# Out:
# Date                    0
# Year                    0
# Locality             1253
# Estimated Value      1243
# Sale Price              0
# Property             1823
# Residential             0
# num_rooms               0
# num_bathrooms           0
# carpet_area          1229
# property_tax_rate       0
# Face                    0
# dtype: int64

# %%
df.isin(['?']).sum()
# Out:
# Date                 0
# Year                 0
# Locality             0
# Estimated Value      0
# Sale Price           0
# Property             0
# Residential          0
# num_rooms            0
# num_bathrooms        0
# carpet_area          0
# property_tax_rate    0
# Face                 0
# dtype: int64

# %% [markdown]
# ### Question 7

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Property             1823
# Locality             1253
# Estimated Value      1243
# carpet_area          1229
# Date                    0
# Year                    0
# Residential             0
# Sale Price              0
# num_rooms               0
# num_bathrooms           0
# property_tax_rate       0
# Face                    0
# dtype: int64

# %% [markdown]
# ### Question 8

# %%
df.dropna(thresh=10, inplace = True)

# %%
df.shape
# Out:
# (9917, 12)

# %% [markdown]
# ### Question 9

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (5449, 12)

# %%
df.isna().sum()
# Out:
# Date                 0
# Year                 0
# Locality             0
# Estimated Value      0
# Sale Price           0
# Property             0
# Residential          0
# num_rooms            0
# num_bathrooms        0
# carpet_area          0
# property_tax_rate    0
# Face                 0
# dtype: int64

# %% [markdown]
# ## Graded 2

# %%
df = pd.read_csv('Week1_GA_dataset.csv')

# %%
df.shape
# Out:
# (10000, 12)

# %%
# dataframe with even number of index
df2 = df.loc[::2]

# %% [markdown]
# ### Question 1

# %%
df2.iloc[0, 3]
# Out:
# np.float64(111440.0)

# %% [markdown]
# ### Question 2

# %%
df2.iloc[332, 3]
# Out:
# np.float64(256200.0)

# %% [markdown]
# ### Question 3

# %%
# dataframe with odd number of index
df3 = df.loc[1::2]

# %%
df3.head()
# Out:
#          Date  Year    Locality  Estimated Value  Sale Price       Property  \
# 1  2009-01-02  2009  Bridgeport         124670.0    150000.0     Two Family
# 3  2009-01-02  2009  Bridgeport        4775276.0    272900.0  Single Family
# 5  2009-01-02  2009   Greenwich        2868880.0   3300000.0  Single Family
# 7  2009-01-02  2009   Greenwich         592760.0    920000.0  Single Family
# 9  2009-01-02  2009  Bridgeport         137901.0    245000.0  Single Family
#
#       Residential  num_rooms  num_bathrooms  carpet_area  property_tax_rate  \
# 1          Duplex          4              3       1241.0           1.025953
# 3  Detached House          3              1        971.0           1.025953
# 5  Detached House          3              1       1039.0           1.025953
# 7  Detached House          3              3        937.0           1.025953
# 9  Detached House          3              1        956.0           1.025953
#
#     Face
# 1  South
# 3   East
# 5  North
# ...

# %%
df3.iloc[332, 3]
# Out:
# np.float64(352940.0)

# %% [markdown]
# ### Question 4

# %%
df.iloc[:, 1::2].iloc[100, 5]
# Out:
# 'West'

# %% [markdown]
# ### Question 5

# %%
# df = pd.read_csv("Week1_GA_dataset.csv")

# %%
# all even rows, all even index
df4 = df.iloc[::2,::2]

# %%
df4.head(3)
# Out:
#          Date    Locality  Sale Price     Residential  num_bathrooms  \
# 0  2009-01-02   Waterbury    185000.0  Detached House              3
# 2  2009-01-02   Waterbury    140000.0  Detached House              2
# 4  2009-01-02  Bridgeport    210000.0  Detached House              2
#
#    property_tax_rate
# 0           1.025953
# 2           1.025953
# 4           1.025953

# %%
df4.iloc[255, 3]
# Out:
# 'Detached House'

# %% [markdown]
# ### Question 6

# %%
year_list = df['Year'].unique()
year_list = year_list[-6:]
year_list
# Out:
# array([2017, 2018, 2019, 2020, 2021, 2022])

# %%
df[df['Year'].isin(year_list)].shape
# Out:
# (4749, 13)

# %% [markdown]
# ### Question 7

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Locality', 'Estimated Value', 'Sale Price', 'Property',
#        'Residential', 'num_rooms', 'num_bathrooms', 'carpet_area',
#        'property_tax_rate', 'Face'],
#       dtype='str')

# %%
df[(df['num_bathrooms'] == 3) & (df['num_rooms'] == 3)]
# Out:
#             Date  Year    Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009   Waterbury         111440.0    185000.0
# 7     2009-01-02  2009   Greenwich         592760.0    920000.0
# 13    2009-01-03  2009   Greenwich        1046920.0    600000.0
# 16    2009-01-05  2009   Waterbury          74620.0    206500.0
# 22    2009-01-08  2009         NaN        1260560.0   1895000.0
# ...          ...   ...         ...              ...         ...
# 9989  2022-09-29  2022    Stamford         373530.0    485000.0
# 9990  2022-09-30  2022         NaN         352030.0    700000.0
# 9991  2022-09-30  2022     Norwalk         344270.0    512500.0
# 9995  2022-09-30  2022  Bridgeport         153660.0    322000.0
# 9998  2022-09-30  2022         NaN         216420.0    415000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...

# %% [markdown]
# ### Question 8

# %%
df[(df['num_bathrooms'] == 3) | (df['num_rooms'] == 3)]
# Out:
#             Date  Year       Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009      Waterbury         111440.0    185000.0
# 1     2009-01-02  2009     Bridgeport         124670.0    150000.0
# 2     2009-01-02  2009      Waterbury          55720.0    140000.0
# 3     2009-01-02  2009     Bridgeport        4775276.0    272900.0
# 4     2009-01-02  2009     Bridgeport         112351.0    210000.0
# ...          ...   ...            ...              ...         ...
# 9993  2022-09-30  2022  West Hartford         121870.0    235000.0
# 9995  2022-09-30  2022     Bridgeport         153660.0    322000.0
# 9997  2022-09-30  2022      Waterbury          83210.0    170000.0
# 9998  2022-09-30  2022            NaN         216420.0    415000.0
# 9999  2022-09-30  2022        Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...

# %% [markdown]
# ### Question 9

# %%
df.columns.to_list()
# Out:
# ['Date',
#  'Year',
#  'Locality',
#  'Estimated Value',
#  'Sale Price',
#  'Property',
#  'Residential',
#  'num_rooms',
#  'num_bathrooms',
#  'carpet_area',
#  'property_tax_rate',
#  'Face']

# %%
df5 = df[(df['Year'] == 2022) & (df['Locality'] == 'Greenwich') & (df['num_rooms'] == 3) & (df.Face.isin(['North', 'East']))]

# %%
df5.shape
# Out:
# (42, 12)

# %% [markdown]
# ### Question 10

# %%
df.sample()
# Out:
#             Date  Year Locality  Estimated Value  Sale Price       Property  \
# 4053  2015-06-27  2015  Norwalk         235410.0    359000.0  Single Family
#
#          Residential  num_rooms  num_bathrooms  carpet_area  \
# 4053  Detached House          3              1        906.0
#
#       property_tax_rate   Face
# 4053           1.340225  South

# %%
df['Month'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')

# %%
df['Month'] = df['Month'].dt.month

# %%
df['Month'].value_counts()
# Out:
# Month
# 6     1128
# 8     1050
# 7     1045
# 5      924
# 9      838
# 12     821
# 10     784
# 4      737
# 11     726
# 3      721
# 1      631
# 2      595
# Name: count, dtype: int64

# %% [markdown]
# ### Question 11

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Locality', 'Estimated Value', 'Sale Price', 'Property',
#        'Residential', 'num_rooms', 'num_bathrooms', 'carpet_area',
#        'property_tax_rate', 'Face', 'Month'],
#       dtype='str')

# %%
df.groupby(['Locality'])['Sale Price'].mean().sort_values(ascending=False)
# Out:
# Locality
# Greenwich        2.270224e+06
# Fairfield        7.277225e+05
# Stamford         6.305313e+05
# Norwalk          5.590959e+05
# West Hartford    3.385472e+05
# Bridgeport       1.740953e+05
# Waterbury        1.062152e+05
# Name: Sale Price, dtype: float64
